# %% [markdown]
# # Import

# %%
import os
import numpy as np
import pandas as pd
import sklearn 

from glob import glob

# vis 
import matplotlib.pyplot as plt
import matplotlib 
import seaborn as sns
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)

import warnings
warnings.filterwarnings("ignore")

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from category_encoders import OrdinalEncoder

# modeling
import pandas as pd 
import numpy as np 

from sklearn.model_selection import KFold
from tqdm import tnrange, tqdm_notebook

import optuna
from optuna.samplers import TPESampler

import lightgbm as lgb
from lightgbm import LGBMRegressor, LGBMClassifier

# 성능 평가
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score , roc_curve
from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix

#
import joblib

# 
from sklearn.cluster import DBSCAN
import lightgbm as lgb
from imblearn.over_sampling import *

# 
# MinMaxScaling
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Load dataset

# %%
X_smote_ = pd.read_csv("..\\..\\data\\X_smote.csv")
y_smote_ = pd.read_csv("..\\..\\data\\y_smote.csv")
# X_train = pd.read_csv("..\\..\\data\\X_train.csv")
# y_train = pd.read_csv("..\\..\\data\\y_train.csv")
X_val_ = pd.read_csv("..\\..\\data\\X_val.csv")
y_val_ = pd.read_csv("..\\..\\data\\y_val.csv")
X_test = pd.read_csv("..\\..\\data\\X_test.csv")
y_test = pd.read_csv("..\\..\\data\\y_test.csv")

# %%
X_smote = X_smote_.copy()
y_smote = y_smote_.copy()
X_val = X_val_.copy()
y_val = y_val_.copy()
X_test = X_test.copy()
y_test = y_test.copy()

# %%
best_params = {'boosting_type': 'dart', 'learning_rate': 0.28233312583283066, 'n_estimators': 600, 'max_depth': 88, 'num_leaves': 241, 'reg_alpha': 0.6801180150569129, 'reg_lambda': 0.2947559972796676, 'subsample': 0.9381561932399759, 'subsample_freq': 8, 'colsample_bytree': 0.6748601998017149, 'min_child_samples': 42, 'max_bin': 100}

# %%
# feature selection by importance of lgbm model
important_var = ["credit_score", "loan_rate", "desired_amount", "age_group", "existing_loan_cnt", 
                 "loan_limit", "credit_score_cat", "gender", "income_type", "purpose", "day", "yearly_income", "product_id_cat", 
                "existing_loan_amt", "employment_type", "total_income", "bank_id_cat", "GetCreditinfo", "houseown_type",
                 "EndLoanApply", "company_year"]

X_smote = X_smote[important_var]
# X_train = X_train[important_var]
X_val = X_val[important_var]
X_test = X_test[important_var]

# %%
# n_estimators.. 400 기준은 없음
clf = LGBMClassifier(**best_params)

evals = [(X_val, y_val)]
clf.fit(X_smote, y_smote, early_stopping_rounds = 100, eval_metric = "auc",
       eval_set = evals, verbose = True)

pred_proba = clf.predict_proba(X_val)[:, 1]
preds = clf.predict(X_val)
# Out:
# [1]	valid_0's auc: 0.749687	valid_0's binary_logloss: 0.609479
# [2]	valid_0's auc: 0.790674	valid_0's binary_logloss: 0.535708
# [3]	valid_0's auc: 0.800046	valid_0's binary_logloss: 0.471734
# [4]	valid_0's auc: 0.807217	valid_0's binary_logloss: 0.431177
# [5]	valid_0's auc: 0.813804	valid_0's binary_logloss: 0.399334
# [6]	valid_0's auc: 0.820405	valid_0's binary_logloss: 0.369708
# [7]	valid_0's auc: 0.823491	valid_0's binary_logloss: 0.337457
# [8]	valid_0's auc: 0.824047	valid_0's binary_logloss: 0.315969
# [9]	valid_0's auc: 0.824822	valid_0's binary_logloss: 0.303254
# [10]	valid_0's auc: 0.825943	valid_0's binary_logloss: 0.290201
# [11]	valid_0's auc: 0.827545	valid_0's binary_logloss: 0.276482
# [12]	valid_0's auc: 0.829085	valid_0's binary_logloss: 0.26723
# [13]	valid_0's auc: 0.830784	valid_0's binary_logloss: 0.25786
# [14]	valid_0's auc: 0.831915	valid_0's binary_logloss: 0.252094
# [15]	valid_0's auc: 0.832263	valid_0's binary_logloss: 0.24903
# [16]	valid_0's auc: 0.833624	valid_0's binary_logloss: 0.243275
# [17]	valid_0's auc: 0.834414	valid_0's binary_logloss: 0.237556
# [18]	valid_0's auc: 0.835982	valid_0's binary_logloss: 0.232617
# [19]	valid_0's auc: 0.836895	valid_0's binary_logloss: 0.228985
# [20]	valid_0's auc: 0.838101	valid_0's binary_logloss: 0.226348
# [21]	valid_0's auc: 0.838303	valid_0's binary_logloss: 0.223961
# [22]	valid_0's auc: 0.838604	valid_0's binary_logloss: 0.221037
# [23]	valid_0's auc: 0.838841	valid_0's binary_logloss: 0.219217
# [24]	valid_0's auc: 0.839118	valid_0's binary_logloss: 0.21718
# [25]	valid_0's auc: 0.839355	valid_0's binary_logloss: 0.215151
# [26]	valid_0's auc: 0.840288	valid_0's binary_logloss: 0.213841
# [27]	valid_0's auc: 0.841425	valid_0's binary_logloss: 0.211917
# [28]	valid_0's auc: 0.841519	valid_0's binary_logloss: 0.210097
# [29]	valid_0's auc: 0.842546	valid_0's binary_logloss: 0.208803
# [30]	valid_0's auc: 0.843764	valid_0's binary_logloss: 0.207444
# [31]	valid_0's auc: 0.844152	valid_0's binary_logloss: 0.206029
# [32]	valid_0's auc: 0.844763	valid_0's binary_logloss: 0.204462
# [33]	valid_0's auc: 0.845312	valid_0's binary_logloss: 0.203172
# [34]	valid_0's auc: 0.845536	valid_0's binary_logloss: 0.202584
# [35]	valid_0's auc: 0.846301	valid_0's binary_logloss: 0.201336
# [36]	valid_0's auc: 0.846169	valid_0's binary_logloss: 0.200212
# [37]	valid_0's auc: 0.846682	valid_0's binary_logloss: 0.199053
# [38]	valid_0's auc: 0.84674	valid_0's binary_logloss: 0.198771
# [39]	valid_0's auc: 0.846679	valid_0's binary_logloss: 0.197719
# [40]	valid_0's auc: 0.846974	valid_0's binary_logloss: 0.19723
# [41]	valid_0's auc: 0.847253	valid_0's binary_logloss: 0.196699
# [42]	valid_0's auc: 0.847306	valid_0's binary_logloss: 0.195933
# [43]	valid_0's auc: 0.847655	valid_0's binary_logloss: 0.195206
# [44]	valid_0's auc: 0.848178	valid_0's binary_logloss: 0.194816
# [45]	valid_0's auc: 0.84845	valid_0's binary_logloss: 0.194164
# [46]	valid_0's auc: 0.848538	valid_0's binary_logloss: 0.19406
# [47]	valid_0's auc: 0.849136	valid_0's binary_logloss: 0.193348
# [48]	valid_0's auc: 0.849692	valid_0's binary_logloss: 0.192911
# [49]	valid_0's auc: 0.849961	valid_0's binary_logloss: 0.19244
# [50]	valid_0's auc: 0.850349	valid_0's binary_logloss: 0.192227
# [51]	valid_0's auc: 0.850646	valid_0's binary_logloss: 0.191678
# [52]	valid_0's auc: 0.851146	valid_0's binary_logloss: 0.191226
# [53]	valid_0's auc: 0.851263	valid_0's binary_logloss: 0.19077
# [54]	valid_0's auc: 0.851416	valid_0's binary_logloss: 0.1903
# [55]	valid_0's auc: 0.851803	valid_0's binary_logloss: 0.189809
# [56]	valid_0's auc: 0.852014	valid_0's binary_logloss: 0.189484
# [57]	valid_0's auc: 0.852281	valid_0's binary_logloss: 0.189221
# [58]	valid_0's auc: 0.85249	valid_0's binary_logloss: 0.188929
# [59]	valid_0's auc: 0.852777	valid_0's binary_logloss: 0.188548
# [60]	valid_0's auc: 0.853021	valid_0's binary_logloss: 0.18822
# [61]	valid_0's auc: 0.853269	valid_0's binary_logloss: 0.187973
# [62]	valid_0's auc: 0.85359	valid_0's binary_logloss: 0.187598
# [63]	valid_0's auc: 0.853823	valid_0's binary_logloss: 0.18734
# [64]	valid_0's auc: 0.854062	valid_0's binary_logloss: 0.187122
# [65]	valid_0's auc: 0.854259	valid_0's binary_logloss: 0.186883
# [66]	valid_0's auc: 0.854383	valid_0's binary_logloss: 0.186736
# [67]	valid_0's auc: 0.854472	valid_0's binary_logloss: 0.186633
# [68]	valid_0's auc: 0.854691	valid_0's binary_logloss: 0.186381
# [69]	valid_0's auc: 0.854841	valid_0's binary_logloss: 0.186222
# [70]	valid_0's auc: 0.855014	valid_0's binary_logloss: 0.186093
# [71]	valid_0's auc: 0.855144	valid_0's binary_logloss: 0.185925
# [72]	valid_0's auc: 0.855269	valid_0's binary_logloss: 0.185709
# [73]	valid_0's auc: 0.85542	valid_0's binary_logloss: 0.185596
# [74]	valid_0's auc: 0.855546	valid_0's binary_logloss: 0.185429
# [75]	valid_0's auc: 0.855628	valid_0's binary_logloss: 0.185264
# [76]	valid_0's auc: 0.855781	valid_0's binary_logloss: 0.185089
# [77]	valid_0's auc: 0.855884	valid_0's binary_logloss: 0.184943
# [78]	valid_0's auc: 0.856018	valid_0's binary_logloss: 0.184535
# [79]	valid_0's auc: 0.856114	valid_0's binary_logloss: 0.184448
# [80]	valid_0's auc: 0.856227	valid_0's binary_logloss: 0.184295
# [81]	valid_0's auc: 0.85634	valid_0's binary_logloss: 0.184231
# [82]	valid_0's auc: 0.856559	valid_0's binary_logloss: 0.184105
# [83]	valid_0's auc: 0.85673	valid_0's binary_logloss: 0.183909
# [84]	valid_0's auc: 0.856931	valid_0's binary_logloss: 0.183718
# [85]	valid_0's auc: 0.857036	valid_0's binary_logloss: 0.183628
# [86]	valid_0's auc: 0.857066	valid_0's binary_logloss: 0.183588
# [87]	valid_0's auc: 0.857199	valid_0's binary_logloss: 0.183494
# [88]	valid_0's auc: 0.857332	valid_0's binary_logloss: 0.183203
# [89]	valid_0's auc: 0.857487	valid_0's binary_logloss: 0.183064
# [90]	valid_0's auc: 0.857556	valid_0's binary_logloss: 0.183007
# [91]	valid_0's auc: 0.857652	valid_0's binary_logloss: 0.182935
# [92]	valid_0's auc: 0.857804	valid_0's binary_logloss: 0.182769
# [93]	valid_0's auc: 0.857881	valid_0's binary_logloss: 0.18269
# [94]	valid_0's auc: 0.857962	valid_0's binary_logloss: 0.182555
# [95]	valid_0's auc: 0.858045	valid_0's binary_logloss: 0.182504
# [96]	valid_0's auc: 0.858201	valid_0's binary_logloss: 0.182369
# [97]	valid_0's auc: 0.85827	valid_0's binary_logloss: 0.18222
# [98]	valid_0's auc: 0.85836	valid_0's binary_logloss: 0.182137
# [99]	valid_0's auc: 0.858433	valid_0's binary_logloss: 0.182067
# [100]	valid_0's auc: 0.858486	valid_0's binary_logloss: 0.181898
# [101]	valid_0's auc: 0.858574	valid_0's binary_logloss: 0.181762
# [102]	valid_0's auc: 0.858601	valid_0's binary_logloss: 0.181694
# [103]	valid_0's auc: 0.858719	valid_0's binary_logloss: 0.181611
# [104]	valid_0's auc: 0.858775	valid_0's binary_logloss: 0.181548
# [105]	valid_0's auc: 0.858888	valid_0's binary_logloss: 0.181448
# [106]	valid_0's auc: 0.858897	valid_0's binary_logloss: 0.1814
# [107]	valid_0's auc: 0.858921	valid_0's binary_logloss: 0.181363
# [108]	valid_0's auc: 0.859024	valid_0's binary_logloss: 0.181275
# [109]	valid_0's auc: 0.859088	valid_0's binary_logloss: 0.181143
# [110]	valid_0's auc: 0.859163	valid_0's binary_logloss: 0.181069
# [111]	valid_0's auc: 0.859278	valid_0's binary_logloss: 0.180928
# [112]	valid_0's auc: 0.859315	valid_0's binary_logloss: 0.18087
# [113]	valid_0's auc: 0.859372	valid_0's binary_logloss: 0.180829
# [114]	valid_0's auc: 0.859428	valid_0's binary_logloss: 0.180776
# [115]	valid_0's auc: 0.859435	valid_0's binary_logloss: 0.180749
# [116]	valid_0's auc: 0.859649	valid_0's binary_logloss: 0.180617
# [117]	valid_0's auc: 0.859699	valid_0's binary_logloss: 0.18048
# [118]	valid_0's auc: 0.859835	valid_0's binary_logloss: 0.180408
# [119]	valid_0's auc: 0.859879	valid_0's binary_logloss: 0.180369
# [120]	valid_0's auc: 0.859962	valid_0's binary_logloss: 0.180299
# [121]	valid_0's auc: 0.860023	valid_0's binary_logloss: 0.180254
# [122]	valid_0's auc: 0.860045	valid_0's binary_logloss: 0.180207
# [123]	valid_0's auc: 0.860111	valid_0's binary_logloss: 0.180162
# [124]	valid_0's auc: 0.860189	valid_0's binary_logloss: 0.180062
# [125]	valid_0's auc: 0.860233	valid_0's binary_logloss: 0.179989
# [126]	valid_0's auc: 0.860277	valid_0's binary_logloss: 0.179909
# [127]	valid_0's auc: 0.86033	valid_0's binary_logloss: 0.179876
# [128]	valid_0's auc: 0.86036	valid_0's binary_logloss: 0.179814
# [129]	valid_0's auc: 0.860436	valid_0's binary_logloss: 0.179746
# [130]	valid_0's auc: 0.860464	valid_0's binary_logloss: 0.179718
# [131]	valid_0's auc: 0.860564	valid_0's binary_logloss: 0.179622
# [132]	valid_0's auc: 0.860619	valid_0's binary_logloss: 0.17955
# [133]	valid_0's auc: 0.86091	valid_0's binary_logloss: 0.179271
# [134]	valid_0's auc: 0.86094	valid_0's binary_logloss: 0.179241
# [135]	valid_0's auc: 0.861004	valid_0's binary_logloss: 0.179184
# [136]	valid_0's auc: 0.8611	valid_0's binary_logloss: 0.179081
# [137]	valid_0's auc: 0.861137	valid_0's binary_logloss: 0.179041
# [138]	valid_0's auc: 0.861236	valid_0's binary_logloss: 0.178942
# [139]	valid_0's auc: 0.861241	valid_0's binary_logloss: 0.178925
# [140]	valid_0's auc: 0.861293	valid_0's binary_logloss: 0.178859
# [141]	valid_0's auc: 0.86131	valid_0's binary_logloss: 0.178821
# [142]	valid_0's auc: 0.861392	valid_0's binary_logloss: 0.178726
# [143]	valid_0's auc: 0.861526	valid_0's binary_logloss: 0.178631
# [144]	valid_0's auc: 0.861628	valid_0's binary_logloss: 0.178552
# [145]	valid_0's auc: 0.861668	valid_0's binary_logloss: 0.178474
# [146]	valid_0's auc: 0.861817	valid_0's binary_logloss: 0.178376
# [147]	valid_0's auc: 0.861914	valid_0's binary_logloss: 0.178292
# [148]	valid_0's auc: 0.861971	valid_0's binary_logloss: 0.178247
# [149]	valid_0's auc: 0.862071	valid_0's binary_logloss: 0.178173
# [150]	valid_0's auc: 0.862158	valid_0's binary_logloss: 0.178102
# [151]	valid_0's auc: 0.862161	valid_0's binary_logloss: 0.178084
# [152]	valid_0's auc: 0.862186	valid_0's binary_logloss: 0.178058
# [153]	valid_0's auc: 0.862213	valid_0's binary_logloss: 0.178025
# [154]	valid_0's auc: 0.862388	valid_0's binary_logloss: 0.177897
# [155]	valid_0's auc: 0.862415	valid_0's binary_logloss: 0.17785
# [156]	valid_0's auc: 0.862434	valid_0's binary_logloss: 0.177797
# [157]	valid_0's auc: 0.862598	valid_0's binary_logloss: 0.177678
# [158]	valid_0's auc: 0.862664	valid_0's binary_logloss: 0.177601
# [159]	valid_0's auc: 0.862726	valid_0's binary_logloss: 0.177547
# [160]	valid_0's auc: 0.862793	valid_0's binary_logloss: 0.177494
# [161]	valid_0's auc: 0.862854	valid_0's binary_logloss: 0.177418
# [162]	valid_0's auc: 0.862894	valid_0's binary_logloss: 0.177391
# [163]	valid_0's auc: 0.862919	valid_0's binary_logloss: 0.177343
# [164]	valid_0's auc: 0.862942	valid_0's binary_logloss: 0.177311
# [165]	valid_0's auc: 0.862999	valid_0's binary_logloss: 0.177258
# [166]	valid_0's auc: 0.863051	valid_0's binary_logloss: 0.177162
# [167]	valid_0's auc: 0.863085	valid_0's binary_logloss: 0.17711
# [168]	valid_0's auc: 0.863121	valid_0's binary_logloss: 0.177078
# [169]	valid_0's auc: 0.863171	valid_0's binary_logloss: 0.177049
# [170]	valid_0's auc: 0.863248	valid_0's binary_logloss: 0.176977
# [171]	valid_0's auc: 0.863313	valid_0's binary_logloss: 0.17691
# [172]	valid_0's auc: 0.863365	valid_0's binary_logloss: 0.17687
# [173]	valid_0's auc: 0.863431	valid_0's binary_logloss: 0.176799
# [174]	valid_0's auc: 0.863481	valid_0's binary_logloss: 0.176774
# [175]	valid_0's auc: 0.863498	valid_0's binary_logloss: 0.176731
# [176]	valid_0's auc: 0.863513	valid_0's binary_logloss: 0.176709
# [177]	valid_0's auc: 0.863571	valid_0's binary_logloss: 0.176652
# [178]	valid_0's auc: 0.863615	valid_0's binary_logloss: 0.176583
# [179]	valid_0's auc: 0.863686	valid_0's binary_logloss: 0.176546
# [180]	valid_0's auc: 0.863694	valid_0's binary_logloss: 0.176513
# [181]	valid_0's auc: 0.863729	valid_0's binary_logloss: 0.176431
# [182]	valid_0's auc: 0.863743	valid_0's binary_logloss: 0.176403
# [183]	valid_0's auc: 0.863775	valid_0's binary_logloss: 0.176358
# [184]	valid_0's auc: 0.863873	valid_0's binary_logloss: 0.176276
# [185]	valid_0's auc: 0.863937	valid_0's binary_logloss: 0.176192
# [186]	valid_0's auc: 0.864	valid_0's binary_logloss: 0.176124
# [187]	valid_0's auc: 0.864094	valid_0's binary_logloss: 0.176051
# [188]	valid_0's auc: 0.864142	valid_0's binary_logloss: 0.176015
# [189]	valid_0's auc: 0.864235	valid_0's binary_logloss: 0.175925
# [190]	valid_0's auc: 0.864304	valid_0's binary_logloss: 0.175865
# [191]	valid_0's auc: 0.864353	valid_0's binary_logloss: 0.175778
# [192]	valid_0's auc: 0.8644	valid_0's binary_logloss: 0.175739
# [193]	valid_0's auc: 0.864436	valid_0's binary_logloss: 0.17569
# [194]	valid_0's auc: 0.864501	valid_0's binary_logloss: 0.175617
# [195]	valid_0's auc: 0.864561	valid_0's binary_logloss: 0.175576
# [196]	valid_0's auc: 0.864613	valid_0's binary_logloss: 0.175522
# [197]	valid_0's auc: 0.864637	valid_0's binary_logloss: 0.175501
# [198]	valid_0's auc: 0.864733	valid_0's binary_logloss: 0.175438
# [199]	valid_0's auc: 0.864798	valid_0's binary_logloss: 0.175365
# [200]	valid_0's auc: 0.864797	valid_0's binary_logloss: 0.17535
# [201]	valid_0's auc: 0.864827	valid_0's binary_logloss: 0.175328
# [202]	valid_0's auc: 0.864843	valid_0's binary_logloss: 0.175312
# [203]	valid_0's auc: 0.86487	valid_0's binary_logloss: 0.175291
# [204]	valid_0's auc: 0.864887	valid_0's binary_logloss: 0.175236
# [205]	valid_0's auc: 0.864931	valid_0's binary_logloss: 0.175214
# [206]	valid_0's auc: 0.864938	valid_0's binary_logloss: 0.175185
# [207]	valid_0's auc: 0.864958	valid_0's binary_logloss: 0.175138
# [208]	valid_0's auc: 0.865052	valid_0's binary_logloss: 0.175081
# [209]	valid_0's auc: 0.865091	valid_0's binary_logloss: 0.17504
# [210]	valid_0's auc: 0.865096	valid_0's binary_logloss: 0.175014
# [211]	valid_0's auc: 0.865098	valid_0's binary_logloss: 0.174999
# [212]	valid_0's auc: 0.865118	valid_0's binary_logloss: 0.174981
# [213]	valid_0's auc: 0.865152	valid_0's binary_logloss: 0.174949
# [214]	valid_0's auc: 0.865195	valid_0's binary_logloss: 0.174907
# [215]	valid_0's auc: 0.865242	valid_0's binary_logloss: 0.174873
# [216]	valid_0's auc: 0.865308	valid_0's binary_logloss: 0.174836
# [217]	valid_0's auc: 0.865339	valid_0's binary_logloss: 0.174787
# [218]	valid_0's auc: 0.865389	valid_0's binary_logloss: 0.17474
# [219]	valid_0's auc: 0.865476	valid_0's binary_logloss: 0.174677
# [220]	valid_0's auc: 0.865565	valid_0's binary_logloss: 0.174606
# [221]	valid_0's auc: 0.865667	valid_0's binary_logloss: 0.174556
# [222]	valid_0's auc: 0.86571	valid_0's binary_logloss: 0.174487
# [223]	valid_0's auc: 0.865726	valid_0's binary_logloss: 0.174474
# [224]	valid_0's auc: 0.865753	valid_0's binary_logloss: 0.174456
# [225]	valid_0's auc: 0.865792	valid_0's binary_logloss: 0.174427
# [226]	valid_0's auc: 0.865813	valid_0's binary_logloss: 0.174372
# [227]	valid_0's auc: 0.865832	valid_0's binary_logloss: 0.174291
# [228]	valid_0's auc: 0.865897	valid_0's binary_logloss: 0.174245
# [229]	valid_0's auc: 0.865918	valid_0's binary_logloss: 0.174228
# [230]	valid_0's auc: 0.865982	valid_0's binary_logloss: 0.174184
# [231]	valid_0's auc: 0.865985	valid_0's binary_logloss: 0.174168
# [232]	valid_0's auc: 0.866011	valid_0's binary_logloss: 0.174131
# [233]	valid_0's auc: 0.866037	valid_0's binary_logloss: 0.174106
# [234]	valid_0's auc: 0.866057	valid_0's binary_logloss: 0.174059
# [235]	valid_0's auc: 0.866086	valid_0's binary_logloss: 0.174021
# [236]	valid_0's auc: 0.866126	valid_0's binary_logloss: 0.173966
# [237]	valid_0's auc: 0.866135	valid_0's binary_logloss: 0.173951
# [238]	valid_0's auc: 0.866174	valid_0's binary_logloss: 0.173913
# [239]	valid_0's auc: 0.866193	valid_0's binary_logloss: 0.173883
# [240]	valid_0's auc: 0.866276	valid_0's binary_logloss: 0.173831
# [241]	valid_0's auc: 0.86633	valid_0's binary_logloss: 0.173772
# [242]	valid_0's auc: 0.866374	valid_0's binary_logloss: 0.173735
# [243]	valid_0's auc: 0.866408	valid_0's binary_logloss: 0.173711
# [244]	valid_0's auc: 0.866417	valid_0's binary_logloss: 0.173677
# [245]	valid_0's auc: 0.866472	valid_0's binary_logloss: 0.173623
# [246]	valid_0's auc: 0.866475	valid_0's binary_logloss: 0.173611
# [247]	valid_0's auc: 0.866513	valid_0's binary_logloss: 0.173564
# [248]	valid_0's auc: 0.866537	valid_0's binary_logloss: 0.173539
# [249]	valid_0's auc: 0.866547	valid_0's binary_logloss: 0.173527
# [250]	valid_0's auc: 0.866559	valid_0's binary_logloss: 0.173498
# [251]	valid_0's auc: 0.866585	valid_0's binary_logloss: 0.17348
# [252]	valid_0's auc: 0.866605	valid_0's binary_logloss: 0.173457
# [253]	valid_0's auc: 0.866663	valid_0's binary_logloss: 0.173424
# [254]	valid_0's auc: 0.866694	valid_0's binary_logloss: 0.173404
# [255]	valid_0's auc: 0.86671	valid_0's binary_logloss: 0.173368
# [256]	valid_0's auc: 0.866725	valid_0's binary_logloss: 0.173337
# [257]	valid_0's auc: 0.866771	valid_0's binary_logloss: 0.173293
# [258]	valid_0's auc: 0.866823	valid_0's binary_logloss: 0.173259
# [259]	valid_0's auc: 0.866852	valid_0's binary_logloss: 0.173222
# [260]	valid_0's auc: 0.866864	valid_0's binary_logloss: 0.173205
# [261]	valid_0's auc: 0.866919	valid_0's binary_logloss: 0.173148
# [262]	valid_0's auc: 0.867009	valid_0's binary_logloss: 0.173099
# [263]	valid_0's auc: 0.867042	valid_0's binary_logloss: 0.173058
# [264]	valid_0's auc: 0.867061	valid_0's binary_logloss: 0.173042
# [265]	valid_0's auc: 0.867104	valid_0's binary_logloss: 0.172972
# [266]	valid_0's auc: 0.86715	valid_0's binary_logloss: 0.172926
# [267]	valid_0's auc: 0.867132	valid_0's binary_logloss: 0.172925
# [268]	valid_0's auc: 0.867158	valid_0's binary_logloss: 0.172872
# [269]	valid_0's auc: 0.867176	valid_0's binary_logloss: 0.17285
# [270]	valid_0's auc: 0.867252	valid_0's binary_logloss: 0.172794
# [271]	valid_0's auc: 0.867304	valid_0's binary_logloss: 0.172749
# [272]	valid_0's auc: 0.867328	valid_0's binary_logloss: 0.172721
# [273]	valid_0's auc: 0.867373	valid_0's binary_logloss: 0.17266
# [274]	valid_0's auc: 0.867395	valid_0's binary_logloss: 0.172637
# [275]	valid_0's auc: 0.867412	valid_0's binary_logloss: 0.172625
# [276]	valid_0's auc: 0.867495	valid_0's binary_logloss: 0.17257
# [277]	valid_0's auc: 0.867545	valid_0's binary_logloss: 0.172528
# [278]	valid_0's auc: 0.867576	valid_0's binary_logloss: 0.172485
# [279]	valid_0's auc: 0.867604	valid_0's binary_logloss: 0.172458
# [280]	valid_0's auc: 0.867625	valid_0's binary_logloss: 0.172419
# [281]	valid_0's auc: 0.867671	valid_0's binary_logloss: 0.172388
# [282]	valid_0's auc: 0.867697	valid_0's binary_logloss: 0.172365
# [283]	valid_0's auc: 0.867708	valid_0's binary_logloss: 0.172342
# [284]	valid_0's auc: 0.867769	valid_0's binary_logloss: 0.172292
# [285]	valid_0's auc: 0.86783	valid_0's binary_logloss: 0.172235
# [286]	valid_0's auc: 0.86785	valid_0's binary_logloss: 0.17221
# [287]	valid_0's auc: 0.867919	valid_0's binary_logloss: 0.172165
# [288]	valid_0's auc: 0.867918	valid_0's binary_logloss: 0.172157
# [289]	valid_0's auc: 0.867966	valid_0's binary_logloss: 0.172126
# [290]	valid_0's auc: 0.868026	valid_0's binary_logloss: 0.172076
# [291]	valid_0's auc: 0.868082	valid_0's binary_logloss: 0.172034
# [292]	valid_0's auc: 0.868101	valid_0's binary_logloss: 0.172016
# [293]	valid_0's auc: 0.868154	valid_0's binary_logloss: 0.171956
# [294]	valid_0's auc: 0.868183	valid_0's binary_logloss: 0.171924
# [295]	valid_0's auc: 0.8682	valid_0's binary_logloss: 0.171908
# [296]	valid_0's auc: 0.8682	valid_0's binary_logloss: 0.171899
# [297]	valid_0's auc: 0.868289	valid_0's binary_logloss: 0.171851
# [298]	valid_0's auc: 0.868308	valid_0's binary_logloss: 0.171831
# [299]	valid_0's auc: 0.868319	valid_0's binary_logloss: 0.171816
# [300]	valid_0's auc: 0.868352	valid_0's binary_logloss: 0.171787
# [301]	valid_0's auc: 0.868448	valid_0's binary_logloss: 0.17173
# [302]	valid_0's auc: 0.868483	valid_0's binary_logloss: 0.171693
# [303]	valid_0's auc: 0.868529	valid_0's binary_logloss: 0.17166
# [304]	valid_0's auc: 0.868553	valid_0's binary_logloss: 0.171642
# [305]	valid_0's auc: 0.868559	valid_0's binary_logloss: 0.171629
# [306]	valid_0's auc: 0.868577	valid_0's binary_logloss: 0.171601
# [307]	valid_0's auc: 0.868592	valid_0's binary_logloss: 0.17158
# [308]	valid_0's auc: 0.868656	valid_0's binary_logloss: 0.171532
# [309]	valid_0's auc: 0.868686	valid_0's binary_logloss: 0.17151
# [310]	valid_0's auc: 0.868741	valid_0's binary_logloss: 0.171465
# [311]	valid_0's auc: 0.868759	valid_0's binary_logloss: 0.171443
# [312]	valid_0's auc: 0.868784	valid_0's binary_logloss: 0.171423
# [313]	valid_0's auc: 0.868806	valid_0's binary_logloss: 0.171407
# [314]	valid_0's auc: 0.86881	valid_0's binary_logloss: 0.171389
# [315]	valid_0's auc: 0.868839	valid_0's binary_logloss: 0.171363
# [316]	valid_0's auc: 0.868838	valid_0's binary_logloss: 0.171355
# [317]	valid_0's auc: 0.868856	valid_0's binary_logloss: 0.171331
# [318]	valid_0's auc: 0.868866	valid_0's binary_logloss: 0.171322
# [319]	valid_0's auc: 0.8689	valid_0's binary_logloss: 0.171293
# [320]	valid_0's auc: 0.86891	valid_0's binary_logloss: 0.17128
# [321]	valid_0's auc: 0.868917	valid_0's binary_logloss: 0.171269
# [322]	valid_0's auc: 0.868955	valid_0's binary_logloss: 0.171235
# [323]	valid_0's auc: 0.868996	valid_0's binary_logloss: 0.171195
# [324]	valid_0's auc: 0.869002	valid_0's binary_logloss: 0.171186
# [325]	valid_0's auc: 0.86902	valid_0's binary_logloss: 0.17116
# [326]	valid_0's auc: 0.869079	valid_0's binary_logloss: 0.171116
# [327]	valid_0's auc: 0.869073	valid_0's binary_logloss: 0.171114
# [328]	valid_0's auc: 0.869094	valid_0's binary_logloss: 0.171093
# [329]	valid_0's auc: 0.869145	valid_0's binary_logloss: 0.171027
# [330]	valid_0's auc: 0.869189	valid_0's binary_logloss: 0.170984
# [331]	valid_0's auc: 0.869203	valid_0's binary_logloss: 0.170974
# [332]	valid_0's auc: 0.869216	valid_0's binary_logloss: 0.170961
# [333]	valid_0's auc: 0.869219	valid_0's binary_logloss: 0.170953
# [334]	valid_0's auc: 0.869224	valid_0's binary_logloss: 0.170942
# [335]	valid_0's auc: 0.869291	valid_0's binary_logloss: 0.170895
# [336]	valid_0's auc: 0.869301	valid_0's binary_logloss: 0.17088
# [337]	valid_0's auc: 0.86933	valid_0's binary_logloss: 0.170849
# [338]	valid_0's auc: 0.869353	valid_0's binary_logloss: 0.170835
# [339]	valid_0's auc: 0.869413	valid_0's binary_logloss: 0.170792
# [340]	valid_0's auc: 0.869437	valid_0's binary_logloss: 0.170771
# [341]	valid_0's auc: 0.869515	valid_0's binary_logloss: 0.170687
# [342]	valid_0's auc: 0.869511	valid_0's binary_logloss: 0.170673
# [343]	valid_0's auc: 0.869527	valid_0's binary_logloss: 0.17064
# [344]	valid_0's auc: 0.869567	valid_0's binary_logloss: 0.170612
# [345]	valid_0's auc: 0.869567	valid_0's binary_logloss: 0.170607
# [346]	valid_0's auc: 0.869571	valid_0's binary_logloss: 0.170587
# [347]	valid_0's auc: 0.86959	valid_0's binary_logloss: 0.170561
# [348]	valid_0's auc: 0.869612	valid_0's binary_logloss: 0.170533
# [349]	valid_0's auc: 0.869673	valid_0's binary_logloss: 0.170493
# [350]	valid_0's auc: 0.869695	valid_0's binary_logloss: 0.17046
# [351]	valid_0's auc: 0.869721	valid_0's binary_logloss: 0.170415
# [352]	valid_0's auc: 0.869732	valid_0's binary_logloss: 0.170397
# [353]	valid_0's auc: 0.869759	valid_0's binary_logloss: 0.170376
# [354]	valid_0's auc: 0.869803	valid_0's binary_logloss: 0.170337
# [355]	valid_0's auc: 0.869828	valid_0's binary_logloss: 0.170299
# [356]	valid_0's auc: 0.869883	valid_0's binary_logloss: 0.170265
# [357]	valid_0's auc: 0.869916	valid_0's binary_logloss: 0.170231
# [358]	valid_0's auc: 0.869996	valid_0's binary_logloss: 0.17018
# [359]	valid_0's auc: 0.870011	valid_0's binary_logloss: 0.170166
# [360]	valid_0's auc: 0.870037	valid_0's binary_logloss: 0.170134
# [361]	valid_0's auc: 0.870042	valid_0's binary_logloss: 0.170127
# [362]	valid_0's auc: 0.87006	valid_0's binary_logloss: 0.170116
# [363]	valid_0's auc: 0.870086	valid_0's binary_logloss: 0.170099
# [364]	valid_0's auc: 0.870089	valid_0's binary_logloss: 0.170084
# [365]	valid_0's auc: 0.870105	valid_0's binary_logloss: 0.170068
# [366]	valid_0's auc: 0.870104	valid_0's binary_logloss: 0.170062
# [367]	valid_0's auc: 0.870122	valid_0's binary_logloss: 0.170043
# [368]	valid_0's auc: 0.870177	valid_0's binary_logloss: 0.170009
# [369]	valid_0's auc: 0.870216	valid_0's binary_logloss: 0.169962
# [370]	valid_0's auc: 0.870265	valid_0's binary_logloss: 0.169931
# [371]	valid_0's auc: 0.870321	valid_0's binary_logloss: 0.169889
# [372]	valid_0's auc: 0.870366	valid_0's binary_logloss: 0.169843
# [373]	valid_0's auc: 0.870395	valid_0's binary_logloss: 0.169824
# [374]	valid_0's auc: 0.870395	valid_0's binary_logloss: 0.169809
# [375]	valid_0's auc: 0.870476	valid_0's binary_logloss: 0.169759
# [376]	valid_0's auc: 0.87052	valid_0's binary_logloss: 0.169727
# [377]	valid_0's auc: 0.870545	valid_0's binary_logloss: 0.169708
# [378]	valid_0's auc: 0.870593	valid_0's binary_logloss: 0.169665
# [379]	valid_0's auc: 0.870615	valid_0's binary_logloss: 0.169647
# [380]	valid_0's auc: 0.870639	valid_0's binary_logloss: 0.16963
# [381]	valid_0's auc: 0.870669	valid_0's binary_logloss: 0.16961
# [382]	valid_0's auc: 0.87071	valid_0's binary_logloss: 0.169581
# [383]	valid_0's auc: 0.870731	valid_0's binary_logloss: 0.169545
# [384]	valid_0's auc: 0.870774	valid_0's binary_logloss: 0.169517
# [385]	valid_0's auc: 0.870784	valid_0's binary_logloss: 0.169509
# [386]	valid_0's auc: 0.8708	valid_0's binary_logloss: 0.169485
# [387]	valid_0's auc: 0.870798	valid_0's binary_logloss: 0.169481
# [388]	valid_0's auc: 0.870828	valid_0's binary_logloss: 0.169459
# [389]	valid_0's auc: 0.870846	valid_0's binary_logloss: 0.169442
# [390]	valid_0's auc: 0.870855	valid_0's binary_logloss: 0.169428
# [391]	valid_0's auc: 0.870864	valid_0's binary_logloss: 0.169417
# [392]	valid_0's auc: 0.870922	valid_0's binary_logloss: 0.16938
# [393]	valid_0's auc: 0.870941	valid_0's binary_logloss: 0.16937
# [394]	valid_0's auc: 0.870949	valid_0's binary_logloss: 0.169356
# [395]	valid_0's auc: 0.870957	valid_0's binary_logloss: 0.169351
# [396]	valid_0's auc: 0.870979	valid_0's binary_logloss: 0.169336
# [397]	valid_0's auc: 0.870989	valid_0's binary_logloss: 0.169325
# [398]	valid_0's auc: 0.870997	valid_0's binary_logloss: 0.169311
# [399]	valid_0's auc: 0.871017	valid_0's binary_logloss: 0.169298
# [400]	valid_0's auc: 0.87101	valid_0's binary_logloss: 0.169296
# [401]	valid_0's auc: 0.871026	valid_0's binary_logloss: 0.169286
# [402]	valid_0's auc: 0.871027	valid_0's binary_logloss: 0.169259
# [403]	valid_0's auc: 0.871061	valid_0's binary_logloss: 0.169227
# [404]	valid_0's auc: 0.871091	valid_0's binary_logloss: 0.169195
# [405]	valid_0's auc: 0.871091	valid_0's binary_logloss: 0.169192
# [406]	valid_0's auc: 0.8711	valid_0's binary_logloss: 0.169185
# [407]	valid_0's auc: 0.87111	valid_0's binary_logloss: 0.169172
# [408]	valid_0's auc: 0.871115	valid_0's binary_logloss: 0.169163
# [409]	valid_0's auc: 0.87118	valid_0's binary_logloss: 0.169123
# [410]	valid_0's auc: 0.871204	valid_0's binary_logloss: 0.169104
# [411]	valid_0's auc: 0.871209	valid_0's binary_logloss: 0.169099
# [412]	valid_0's auc: 0.871227	valid_0's binary_logloss: 0.169075
# [413]	valid_0's auc: 0.871236	valid_0's binary_logloss: 0.16906
# [414]	valid_0's auc: 0.871239	valid_0's binary_logloss: 0.169053
# [415]	valid_0's auc: 0.871249	valid_0's binary_logloss: 0.169035
# [416]	valid_0's auc: 0.87127	valid_0's binary_logloss: 0.169005
# [417]	valid_0's auc: 0.87126	valid_0's binary_logloss: 0.169004
# [418]	valid_0's auc: 0.871273	valid_0's binary_logloss: 0.168978
# [419]	valid_0's auc: 0.871303	valid_0's binary_logloss: 0.168963
# [420]	valid_0's auc: 0.871315	valid_0's binary_logloss: 0.168953
# [421]	valid_0's auc: 0.871352	valid_0's binary_logloss: 0.168921
# [422]	valid_0's auc: 0.871391	valid_0's binary_logloss: 0.168896
# [423]	valid_0's auc: 0.871423	valid_0's binary_logloss: 0.168856
# [424]	valid_0's auc: 0.871427	valid_0's binary_logloss: 0.168848
# [425]	valid_0's auc: 0.871431	valid_0's binary_logloss: 0.168826
# [426]	valid_0's auc: 0.871493	valid_0's binary_logloss: 0.168791
# [427]	valid_0's auc: 0.871497	valid_0's binary_logloss: 0.168787
# [428]	valid_0's auc: 0.871534	valid_0's binary_logloss: 0.168752
# [429]	valid_0's auc: 0.871551	valid_0's binary_logloss: 0.168742
# [430]	valid_0's auc: 0.871558	valid_0's binary_logloss: 0.168723
# [431]	valid_0's auc: 0.871569	valid_0's binary_logloss: 0.168704
# [432]	valid_0's auc: 0.871587	valid_0's binary_logloss: 0.168687
# [433]	valid_0's auc: 0.871609	valid_0's binary_logloss: 0.168664
# [434]	valid_0's auc: 0.871631	valid_0's binary_logloss: 0.168634
# [435]	valid_0's auc: 0.87167	valid_0's binary_logloss: 0.168608
# [436]	valid_0's auc: 0.871693	valid_0's binary_logloss: 0.168589
# [437]	valid_0's auc: 0.87169	valid_0's binary_logloss: 0.168587
# [438]	valid_0's auc: 0.871795	valid_0's binary_logloss: 0.168526
# [439]	valid_0's auc: 0.871806	valid_0's binary_logloss: 0.168506
# [440]	valid_0's auc: 0.871808	valid_0's binary_logloss: 0.168492
# [441]	valid_0's auc: 0.871823	valid_0's binary_logloss: 0.168474
# [442]	valid_0's auc: 0.871817	valid_0's binary_logloss: 0.168474
# [443]	valid_0's auc: 0.871837	valid_0's binary_logloss: 0.168458
# [444]	valid_0's auc: 0.871899	valid_0's binary_logloss: 0.16841
# [445]	valid_0's auc: 0.871936	valid_0's binary_logloss: 0.168374
# [446]	valid_0's auc: 0.871927	valid_0's binary_logloss: 0.168364
# [447]	valid_0's auc: 0.871956	valid_0's binary_logloss: 0.168342
# [448]	valid_0's auc: 0.871958	valid_0's binary_logloss: 0.168336
# [449]	valid_0's auc: 0.871986	valid_0's binary_logloss: 0.168318
# [450]	valid_0's auc: 0.872003	valid_0's binary_logloss: 0.168308
# [451]	valid_0's auc: 0.872035	valid_0's binary_logloss: 0.168255
# [452]	valid_0's auc: 0.872066	valid_0's binary_logloss: 0.168238
# [453]	valid_0's auc: 0.872076	valid_0's binary_logloss: 0.168229
# [454]	valid_0's auc: 0.872107	valid_0's binary_logloss: 0.168207
# [455]	valid_0's auc: 0.872137	valid_0's binary_logloss: 0.168184
# [456]	valid_0's auc: 0.872177	valid_0's binary_logloss: 0.168147
# [457]	valid_0's auc: 0.872194	valid_0's binary_logloss: 0.168123
# [458]	valid_0's auc: 0.872222	valid_0's binary_logloss: 0.168093
# [459]	valid_0's auc: 0.872237	valid_0's binary_logloss: 0.168074
# [460]	valid_0's auc: 0.872271	valid_0's binary_logloss: 0.168049
# [461]	valid_0's auc: 0.872319	valid_0's binary_logloss: 0.168011
# [462]	valid_0's auc: 0.872362	valid_0's binary_logloss: 0.167982
# [463]	valid_0's auc: 0.87238	valid_0's binary_logloss: 0.167961
# [464]	valid_0's auc: 0.872399	valid_0's binary_logloss: 0.167948
# [465]	valid_0's auc: 0.872404	valid_0's binary_logloss: 0.167931
# [466]	valid_0's auc: 0.872428	valid_0's binary_logloss: 0.167902
# [467]	valid_0's auc: 0.87246	valid_0's binary_logloss: 0.167881
# [468]	valid_0's auc: 0.872467	valid_0's binary_logloss: 0.167868
# [469]	valid_0's auc: 0.872502	valid_0's binary_logloss: 0.167825
# [470]	valid_0's auc: 0.872497	valid_0's binary_logloss: 0.167822
# [471]	valid_0's auc: 0.872511	valid_0's binary_logloss: 0.167812
# [472]	valid_0's auc: 0.872559	valid_0's binary_logloss: 0.167781
# [473]	valid_0's auc: 0.87257	valid_0's binary_logloss: 0.167768
# [474]	valid_0's auc: 0.872593	valid_0's binary_logloss: 0.167745
# [475]	valid_0's auc: 0.872603	valid_0's binary_logloss: 0.167735
# [476]	valid_0's auc: 0.872612	valid_0's binary_logloss: 0.167708
# [477]	valid_0's auc: 0.872645	valid_0's binary_logloss: 0.167683
# [478]	valid_0's auc: 0.872649	valid_0's binary_logloss: 0.167677
# [479]	valid_0's auc: 0.872692	valid_0's binary_logloss: 0.167643
# [480]	valid_0's auc: 0.872734	valid_0's binary_logloss: 0.167623
# [481]	valid_0's auc: 0.872749	valid_0's binary_logloss: 0.167605
# [482]	valid_0's auc: 0.872762	valid_0's binary_logloss: 0.167571
# [483]	valid_0's auc: 0.872789	valid_0's binary_logloss: 0.167547
# [484]	valid_0's auc: 0.872803	valid_0's binary_logloss: 0.167536
# [485]	valid_0's auc: 0.872831	valid_0's binary_logloss: 0.16751
# [486]	valid_0's auc: 0.872875	valid_0's binary_logloss: 0.167479
# [487]	valid_0's auc: 0.872924	valid_0's binary_logloss: 0.167445
# [488]	valid_0's auc: 0.87296	valid_0's binary_logloss: 0.167419
# [489]	valid_0's auc: 0.87298	valid_0's binary_logloss: 0.167404
# [490]	valid_0's auc: 0.873037	valid_0's binary_logloss: 0.167368
# [491]	valid_0's auc: 0.87304	valid_0's binary_logloss: 0.16736
# [492]	valid_0's auc: 0.873045	valid_0's binary_logloss: 0.167352
# [493]	valid_0's auc: 0.873049	valid_0's binary_logloss: 0.167342
# [494]	valid_0's auc: 0.873039	valid_0's binary_logloss: 0.167337
# [495]	valid_0's auc: 0.873083	valid_0's binary_logloss: 0.167313
# [496]	valid_0's auc: 0.87312	valid_0's binary_logloss: 0.167286
# [497]	valid_0's auc: 0.87315	valid_0's binary_logloss: 0.167256
# [498]	valid_0's auc: 0.873199	valid_0's binary_logloss: 0.167227
# [499]	valid_0's auc: 0.873213	valid_0's binary_logloss: 0.167217
# [500]	valid_0's auc: 0.873229	valid_0's binary_logloss: 0.167204
# [501]	valid_0's auc: 0.873279	valid_0's binary_logloss: 0.167174
# [502]	valid_0's auc: 0.873286	valid_0's binary_logloss: 0.167157
# [503]	valid_0's auc: 0.873331	valid_0's binary_logloss: 0.167123
# [504]	valid_0's auc: 0.873321	valid_0's binary_logloss: 0.16712
# [505]	valid_0's auc: 0.873344	valid_0's binary_logloss: 0.167096
# [506]	valid_0's auc: 0.873345	valid_0's binary_logloss: 0.16709
# [507]	valid_0's auc: 0.873361	valid_0's binary_logloss: 0.167071
# [508]	valid_0's auc: 0.873385	valid_0's binary_logloss: 0.167053
# [509]	valid_0's auc: 0.873415	valid_0's binary_logloss: 0.16703
# [510]	valid_0's auc: 0.873433	valid_0's binary_logloss: 0.167018
# [511]	valid_0's auc: 0.873425	valid_0's binary_logloss: 0.167018
# [512]	valid_0's auc: 0.873433	valid_0's binary_logloss: 0.167006
# [513]	valid_0's auc: 0.873428	valid_0's binary_logloss: 0.167002
# [514]	valid_0's auc: 0.873444	valid_0's binary_logloss: 0.166992
# [515]	valid_0's auc: 0.873462	valid_0's binary_logloss: 0.166979
# [516]	valid_0's auc: 0.87348	valid_0's binary_logloss: 0.166956
# [517]	valid_0's auc: 0.873499	valid_0's binary_logloss: 0.166932
# [518]	valid_0's auc: 0.873527	valid_0's binary_logloss: 0.166911
# [519]	valid_0's auc: 0.873525	valid_0's binary_logloss: 0.166899
# [520]	valid_0's auc: 0.873549	valid_0's binary_logloss: 0.166875
# [521]	valid_0's auc: 0.873576	valid_0's binary_logloss: 0.166852
# [522]	valid_0's auc: 0.873595	valid_0's binary_logloss: 0.166831
# [523]	valid_0's auc: 0.873618	valid_0's binary_logloss: 0.16681
# [524]	valid_0's auc: 0.873644	valid_0's binary_logloss: 0.166785
# [525]	valid_0's auc: 0.873642	valid_0's binary_logloss: 0.166783
# [526]	valid_0's auc: 0.87367	valid_0's binary_logloss: 0.166755
# [527]	valid_0's auc: 0.873707	valid_0's binary_logloss: 0.166736
# [528]	valid_0's auc: 0.873733	valid_0's binary_logloss: 0.166714
# [529]	valid_0's auc: 0.873745	valid_0's binary_logloss: 0.166699
# [530]	valid_0's auc: 0.873753	valid_0's binary_logloss: 0.16668
# [531]	valid_0's auc: 0.873755	valid_0's binary_logloss: 0.166668
# [532]	valid_0's auc: 0.873759	valid_0's binary_logloss: 0.166647
# [533]	valid_0's auc: 0.873789	valid_0's binary_logloss: 0.166626
# [534]	valid_0's auc: 0.873789	valid_0's binary_logloss: 0.166619
# [535]	valid_0's auc: 0.873789	valid_0's binary_logloss: 0.166618
# [536]	valid_0's auc: 0.873803	valid_0's binary_logloss: 0.166597
# [537]	valid_0's auc: 0.873828	valid_0's binary_logloss: 0.166578
# [538]	valid_0's auc: 0.87386	valid_0's binary_logloss: 0.166554
# [539]	valid_0's auc: 0.873858	valid_0's binary_logloss: 0.166541
# [540]	valid_0's auc: 0.873881	valid_0's binary_logloss: 0.166528
# [541]	valid_0's auc: 0.873902	valid_0's binary_logloss: 0.166502
# [542]	valid_0's auc: 0.873921	valid_0's binary_logloss: 0.166485
# [543]	valid_0's auc: 0.873917	valid_0's binary_logloss: 0.166481
# [544]	valid_0's auc: 0.873932	valid_0's binary_logloss: 0.166467
# [545]	valid_0's auc: 0.873971	valid_0's binary_logloss: 0.166444
# [546]	valid_0's auc: 0.873968	valid_0's binary_logloss: 0.166443
# [547]	valid_0's auc: 0.873997	valid_0's binary_logloss: 0.16643
# [548]	valid_0's auc: 0.874003	valid_0's binary_logloss: 0.166415
# [549]	valid_0's auc: 0.874015	valid_0's binary_logloss: 0.166402
# [550]	valid_0's auc: 0.874028	valid_0's binary_logloss: 0.166384
# [551]	valid_0's auc: 0.874042	valid_0's binary_logloss: 0.166373
# [552]	valid_0's auc: 0.874047	valid_0's binary_logloss: 0.166367
# [553]	valid_0's auc: 0.874055	valid_0's binary_logloss: 0.166353
# [554]	valid_0's auc: 0.874075	valid_0's binary_logloss: 0.16633
# [555]	valid_0's auc: 0.874124	valid_0's binary_logloss: 0.166288
# [556]	valid_0's auc: 0.874132	valid_0's binary_logloss: 0.166275
# [557]	valid_0's auc: 0.874142	valid_0's binary_logloss: 0.166264
# [558]	valid_0's auc: 0.874148	valid_0's binary_logloss: 0.166254
# [559]	valid_0's auc: 0.874149	valid_0's binary_logloss: 0.166245
# [560]	valid_0's auc: 0.874142	valid_0's binary_logloss: 0.166239
# [561]	valid_0's auc: 0.874143	valid_0's binary_logloss: 0.166222
# [562]	valid_0's auc: 0.87417	valid_0's binary_logloss: 0.166208
# [563]	valid_0's auc: 0.874199	valid_0's binary_logloss: 0.166182
# [564]	valid_0's auc: 0.874268	valid_0's binary_logloss: 0.16614
# [565]	valid_0's auc: 0.87427	valid_0's binary_logloss: 0.166128
# [566]	valid_0's auc: 0.87428	valid_0's binary_logloss: 0.166117
# [567]	valid_0's auc: 0.874306	valid_0's binary_logloss: 0.166097
# [568]	valid_0's auc: 0.87433	valid_0's binary_logloss: 0.166082
# [569]	valid_0's auc: 0.874334	valid_0's binary_logloss: 0.166074
# [570]	valid_0's auc: 0.874363	valid_0's binary_logloss: 0.16605
# [571]	valid_0's auc: 0.874376	valid_0's binary_logloss: 0.166041
# [572]	valid_0's auc: 0.874394	valid_0's binary_logloss: 0.166026
# [573]	valid_0's auc: 0.874396	valid_0's binary_logloss: 0.166021
# [574]	valid_0's auc: 0.874391	valid_0's binary_logloss: 0.166019
# [575]	valid_0's auc: 0.874402	valid_0's binary_logloss: 0.166013
# [576]	valid_0's auc: 0.874441	valid_0's binary_logloss: 0.165994
# [577]	valid_0's auc: 0.874452	valid_0's binary_logloss: 0.165989
# [578]	valid_0's auc: 0.874468	valid_0's binary_logloss: 0.165979
# [579]	valid_0's auc: 0.874479	valid_0's binary_logloss: 0.165973
# [580]	valid_0's auc: 0.874507	valid_0's binary_logloss: 0.165949
# [581]	valid_0's auc: 0.874522	valid_0's binary_logloss: 0.165937
# [582]	valid_0's auc: 0.874534	valid_0's binary_logloss: 0.165926
# [583]	valid_0's auc: 0.874535	valid_0's binary_logloss: 0.165922
# [584]	valid_0's auc: 0.874555	valid_0's binary_logloss: 0.165907
# [585]	valid_0's auc: 0.874569	valid_0's binary_logloss: 0.165897
# [586]	valid_0's auc: 0.874582	valid_0's binary_logloss: 0.165881
# [587]	valid_0's auc: 0.874632	valid_0's binary_logloss: 0.16585
# [588]	valid_0's auc: 0.874661	valid_0's binary_logloss: 0.165833
# [589]	valid_0's auc: 0.87467	valid_0's binary_logloss: 0.165824
# [590]	valid_0's auc: 0.874686	valid_0's binary_logloss: 0.16581
# [591]	valid_0's auc: 0.87471	valid_0's binary_logloss: 0.165795
# [592]	valid_0's auc: 0.874738	valid_0's binary_logloss: 0.165779
# [593]	valid_0's auc: 0.874757	valid_0's binary_logloss: 0.165761
# [594]	valid_0's auc: 0.874769	valid_0's binary_logloss: 0.165746
# [595]	valid_0's auc: 0.874785	valid_0's binary_logloss: 0.165732
# [596]	valid_0's auc: 0.874812	valid_0's binary_logloss: 0.165703
# [597]	valid_0's auc: 0.874832	valid_0's binary_logloss: 0.16569
# [598]	valid_0's auc: 0.874835	valid_0's binary_logloss: 0.16568
# [599]	valid_0's auc: 0.874859	valid_0's binary_logloss: 0.165663
# [600]	valid_0's auc: 0.874869	valid_0's binary_logloss: 0.165649
# [601]	valid_0's auc: 0.874899	valid_0's binary_logloss: 0.16562
# [602]	valid_0's auc: 0.874915	valid_0's binary_logloss: 0.165606
# [603]	valid_0's auc: 0.874918	valid_0's binary_logloss: 0.165596
# [604]	valid_0's auc: 0.874941	valid_0's binary_logloss: 0.165566
# [605]	valid_0's auc: 0.874968	valid_0's binary_logloss: 0.165542
# [606]	valid_0's auc: 0.875012	valid_0's binary_logloss: 0.165521
# [607]	valid_0's auc: 0.875018	valid_0's binary_logloss: 0.165512
# [608]	valid_0's auc: 0.875079	valid_0's binary_logloss: 0.165476
# [609]	valid_0's auc: 0.875081	valid_0's binary_logloss: 0.165464
# [610]	valid_0's auc: 0.875113	valid_0's binary_logloss: 0.165445
# [611]	valid_0's auc: 0.875152	valid_0's binary_logloss: 0.165417
# [612]	valid_0's auc: 0.875153	valid_0's binary_logloss: 0.16541
# [613]	valid_0's auc: 0.875165	valid_0's binary_logloss: 0.165398
# [614]	valid_0's auc: 0.875169	valid_0's binary_logloss: 0.165392
# [615]	valid_0's auc: 0.875189	valid_0's binary_logloss: 0.165377
# [616]	valid_0's auc: 0.87521	valid_0's binary_logloss: 0.165362
# [617]	valid_0's auc: 0.875213	valid_0's binary_logloss: 0.165355
# [618]	valid_0's auc: 0.875266	valid_0's binary_logloss: 0.165317
# [619]	valid_0's auc: 0.875285	valid_0's binary_logloss: 0.1653
# [620]	valid_0's auc: 0.875295	valid_0's binary_logloss: 0.165288
# [621]	valid_0's auc: 0.8753	valid_0's binary_logloss: 0.165277
# [622]	valid_0's auc: 0.875329	valid_0's binary_logloss: 0.165258
# [623]	valid_0's auc: 0.875347	valid_0's binary_logloss: 0.165247
# [624]	valid_0's auc: 0.875391	valid_0's binary_logloss: 0.165216
# [625]	valid_0's auc: 0.875411	valid_0's binary_logloss: 0.165206
# [626]	valid_0's auc: 0.875408	valid_0's binary_logloss: 0.165196
# [627]	valid_0's auc: 0.875435	valid_0's binary_logloss: 0.165178
# [628]	valid_0's auc: 0.875465	valid_0's binary_logloss: 0.165152
# [629]	valid_0's auc: 0.875475	valid_0's binary_logloss: 0.165146
# [630]	valid_0's auc: 0.875498	valid_0's binary_logloss: 0.165128
# [631]	valid_0's auc: 0.875518	valid_0's binary_logloss: 0.165106
# [632]	valid_0's auc: 0.875513	valid_0's binary_logloss: 0.165102
# [633]	valid_0's auc: 0.875514	valid_0's binary_logloss: 0.165099
# [634]	valid_0's auc: 0.875524	valid_0's binary_logloss: 0.16508
# [635]	valid_0's auc: 0.87553	valid_0's binary_logloss: 0.165074
# [636]	valid_0's auc: 0.875595	valid_0's binary_logloss: 0.165031
# [637]	valid_0's auc: 0.875596	valid_0's binary_logloss: 0.165027
# [638]	valid_0's auc: 0.875621	valid_0's binary_logloss: 0.16501
# [639]	valid_0's auc: 0.875618	valid_0's binary_logloss: 0.165007
# [640]	valid_0's auc: 0.875629	valid_0's binary_logloss: 0.164999
# [641]	valid_0's auc: 0.87563	valid_0's binary_logloss: 0.164989
# [642]	valid_0's auc: 0.875658	valid_0's binary_logloss: 0.164961
# [643]	valid_0's auc: 0.875653	valid_0's binary_logloss: 0.164961
# [644]	valid_0's auc: 0.875679	valid_0's binary_logloss: 0.164945
# [645]	valid_0's auc: 0.875711	valid_0's binary_logloss: 0.164927
# [646]	valid_0's auc: 0.875719	valid_0's binary_logloss: 0.164922
# [647]	valid_0's auc: 0.875729	valid_0's binary_logloss: 0.164916
# [648]	valid_0's auc: 0.875739	valid_0's binary_logloss: 0.164903
# [649]	valid_0's auc: 0.875757	valid_0's binary_logloss: 0.164886
# [650]	valid_0's auc: 0.875756	valid_0's binary_logloss: 0.164877
# [651]	valid_0's auc: 0.875788	valid_0's binary_logloss: 0.164845
# [652]	valid_0's auc: 0.875815	valid_0's binary_logloss: 0.164824
# [653]	valid_0's auc: 0.875828	valid_0's binary_logloss: 0.164811
# [654]	valid_0's auc: 0.875828	valid_0's binary_logloss: 0.164807
# [655]	valid_0's auc: 0.87588	valid_0's binary_logloss: 0.164773
# [656]	valid_0's auc: 0.8759	valid_0's binary_logloss: 0.164755
# [657]	valid_0's auc: 0.875922	valid_0's binary_logloss: 0.164738
# [658]	valid_0's auc: 0.875959	valid_0's binary_logloss: 0.164708
# [659]	valid_0's auc: 0.875989	valid_0's binary_logloss: 0.164692
# [660]	valid_0's auc: 0.875994	valid_0's binary_logloss: 0.16468
# [661]	valid_0's auc: 0.876029	valid_0's binary_logloss: 0.164661
# [662]	valid_0's auc: 0.876037	valid_0's binary_logloss: 0.164644
# [663]	valid_0's auc: 0.876057	valid_0's binary_logloss: 0.164631
# [664]	valid_0's auc: 0.87607	valid_0's binary_logloss: 0.164618
# [665]	valid_0's auc: 0.87609	valid_0's binary_logloss: 0.164604
# [666]	valid_0's auc: 0.876103	valid_0's binary_logloss: 0.164587
# [667]	valid_0's auc: 0.876119	valid_0's binary_logloss: 0.164574
# [668]	valid_0's auc: 0.876133	valid_0's binary_logloss: 0.164555
# [669]	valid_0's auc: 0.876137	valid_0's binary_logloss: 0.16454
# [670]	valid_0's auc: 0.87617	valid_0's binary_logloss: 0.164522
# [671]	valid_0's auc: 0.876175	valid_0's binary_logloss: 0.164517
# [672]	valid_0's auc: 0.876193	valid_0's binary_logloss: 0.164492
# [673]	valid_0's auc: 0.876193	valid_0's binary_logloss: 0.164486
# [674]	valid_0's auc: 0.876199	valid_0's binary_logloss: 0.164481
# [675]	valid_0's auc: 0.876232	valid_0's binary_logloss: 0.164457
# [676]	valid_0's auc: 0.87625	valid_0's binary_logloss: 0.164438
# [677]	valid_0's auc: 0.876291	valid_0's binary_logloss: 0.164411
# [678]	valid_0's auc: 0.876302	valid_0's binary_logloss: 0.164403
# [679]	valid_0's auc: 0.876334	valid_0's binary_logloss: 0.164379
# [680]	valid_0's auc: 0.876336	valid_0's binary_logloss: 0.164375
# [681]	valid_0's auc: 0.87635	valid_0's binary_logloss: 0.164362
# [682]	valid_0's auc: 0.87635	valid_0's binary_logloss: 0.164359
# [683]	valid_0's auc: 0.876365	valid_0's binary_logloss: 0.164348
# [684]	valid_0's auc: 0.876372	valid_0's binary_logloss: 0.164328
# [685]	valid_0's auc: 0.876391	valid_0's binary_logloss: 0.164317
# [686]	valid_0's auc: 0.876395	valid_0's binary_logloss: 0.164308
# [687]	valid_0's auc: 0.876403	valid_0's binary_logloss: 0.164287
# [688]	valid_0's auc: 0.876408	valid_0's binary_logloss: 0.164282
# [689]	valid_0's auc: 0.876421	valid_0's binary_logloss: 0.164272
# [690]	valid_0's auc: 0.876441	valid_0's binary_logloss: 0.164256
# [691]	valid_0's auc: 0.876458	valid_0's binary_logloss: 0.164247
# [692]	valid_0's auc: 0.876469	valid_0's binary_logloss: 0.164232
# [693]	valid_0's auc: 0.876482	valid_0's binary_logloss: 0.16422
# [694]	valid_0's auc: 0.876496	valid_0's binary_logloss: 0.164208
# [695]	valid_0's auc: 0.876508	valid_0's binary_logloss: 0.1642
# [696]	valid_0's auc: 0.876523	valid_0's binary_logloss: 0.164192
# [697]	valid_0's auc: 0.876537	valid_0's binary_logloss: 0.164182
# [698]	valid_0's auc: 0.876537	valid_0's binary_logloss: 0.164175
# [699]	valid_0's auc: 0.876537	valid_0's binary_logloss: 0.164169
# [700]	valid_0's auc: 0.876548	valid_0's binary_logloss: 0.164161
# [701]	valid_0's auc: 0.876553	valid_0's binary_logloss: 0.164152
# [702]	valid_0's auc: 0.876565	valid_0's binary_logloss: 0.16414
# [703]	valid_0's auc: 0.876571	valid_0's binary_logloss: 0.164127
# [704]	valid_0's auc: 0.876591	valid_0's binary_logloss: 0.164111
# [705]	valid_0's auc: 0.87659	valid_0's binary_logloss: 0.164104
# [706]	valid_0's auc: 0.876594	valid_0's binary_logloss: 0.164101
# [707]	valid_0's auc: 0.876602	valid_0's binary_logloss: 0.164086
# [708]	valid_0's auc: 0.876624	valid_0's binary_logloss: 0.16407
# [709]	valid_0's auc: 0.876655	valid_0's binary_logloss: 0.164049
# [710]	valid_0's auc: 0.876676	valid_0's binary_logloss: 0.164027
# [711]	valid_0's auc: 0.876674	valid_0's binary_logloss: 0.164021
# [712]	valid_0's auc: 0.876711	valid_0's binary_logloss: 0.16399
# [713]	valid_0's auc: 0.876717	valid_0's binary_logloss: 0.163978
# [714]	valid_0's auc: 0.876729	valid_0's binary_logloss: 0.16396
# [715]	valid_0's auc: 0.876733	valid_0's binary_logloss: 0.163954
# [716]	valid_0's auc: 0.876748	valid_0's binary_logloss: 0.16394
# [717]	valid_0's auc: 0.876771	valid_0's binary_logloss: 0.163921
# [718]	valid_0's auc: 0.876785	valid_0's binary_logloss: 0.163901
# [719]	valid_0's auc: 0.8768	valid_0's binary_logloss: 0.163886
# [720]	valid_0's auc: 0.876819	valid_0's binary_logloss: 0.163873
# [721]	valid_0's auc: 0.876836	valid_0's binary_logloss: 0.163862
# [722]	valid_0's auc: 0.876849	valid_0's binary_logloss: 0.16385
# [723]	valid_0's auc: 0.876873	valid_0's binary_logloss: 0.163825
# [724]	valid_0's auc: 0.876889	valid_0's binary_logloss: 0.163815
# [725]	valid_0's auc: 0.876911	valid_0's binary_logloss: 0.163802
# [726]	valid_0's auc: 0.87691	valid_0's binary_logloss: 0.163799
# [727]	valid_0's auc: 0.87693	valid_0's binary_logloss: 0.163782
# [728]	valid_0's auc: 0.87695	valid_0's binary_logloss: 0.163771
# [729]	valid_0's auc: 0.876949	valid_0's binary_logloss: 0.16377
# [730]	valid_0's auc: 0.876961	valid_0's binary_logloss: 0.163757
# [731]	valid_0's auc: 0.876972	valid_0's binary_logloss: 0.163748
# [732]	valid_0's auc: 0.876996	valid_0's binary_logloss: 0.163728
# [733]	valid_0's auc: 0.877007	valid_0's binary_logloss: 0.163721
# [734]	valid_0's auc: 0.877017	valid_0's binary_logloss: 0.163715
# [735]	valid_0's auc: 0.877031	valid_0's binary_logloss: 0.163703
# [736]	valid_0's auc: 0.877026	valid_0's binary_logloss: 0.163697
# [737]	valid_0's auc: 0.877022	valid_0's binary_logloss: 0.163702
# [738]	valid_0's auc: 0.877029	valid_0's binary_logloss: 0.163693
# [739]	valid_0's auc: 0.877049	valid_0's binary_logloss: 0.163677
# [740]	valid_0's auc: 0.877065	valid_0's binary_logloss: 0.163666
# [741]	valid_0's auc: 0.877072	valid_0's binary_logloss: 0.163655
# [742]	valid_0's auc: 0.877073	valid_0's binary_logloss: 0.163654
# [743]	valid_0's auc: 0.877073	valid_0's binary_logloss: 0.163644
# [744]	valid_0's auc: 0.877088	valid_0's binary_logloss: 0.163628
# [745]	valid_0's auc: 0.877083	valid_0's binary_logloss: 0.163628
# [746]	valid_0's auc: 0.877091	valid_0's binary_logloss: 0.163624
# [747]	valid_0's auc: 0.877089	valid_0's binary_logloss: 0.163626
# [748]	valid_0's auc: 0.877091	valid_0's binary_logloss: 0.163623
# [749]	valid_0's auc: 0.877119	valid_0's binary_logloss: 0.163608
# [750]	valid_0's auc: 0.877144	valid_0's binary_logloss: 0.16359
# [751]	valid_0's auc: 0.877149	valid_0's binary_logloss: 0.163571
# [752]	valid_0's auc: 0.87715	valid_0's binary_logloss: 0.163562
# [753]	valid_0's auc: 0.877154	valid_0's binary_logloss: 0.163557
# [754]	valid_0's auc: 0.877172	valid_0's binary_logloss: 0.163542
# [755]	valid_0's auc: 0.877182	valid_0's binary_logloss: 0.163536
# [756]	valid_0's auc: 0.877195	valid_0's binary_logloss: 0.163531
# [757]	valid_0's auc: 0.877221	valid_0's binary_logloss: 0.163517
# [758]	valid_0's auc: 0.877225	valid_0's binary_logloss: 0.163512
# [759]	valid_0's auc: 0.877251	valid_0's binary_logloss: 0.163496
# [760]	valid_0's auc: 0.877257	valid_0's binary_logloss: 0.163478
# [761]	valid_0's auc: 0.877261	valid_0's binary_logloss: 0.163464
# [762]	valid_0's auc: 0.877288	valid_0's binary_logloss: 0.163444
# [763]	valid_0's auc: 0.877291	valid_0's binary_logloss: 0.163437
# [764]	valid_0's auc: 0.877345	valid_0's binary_logloss: 0.163405
# [765]	valid_0's auc: 0.877341	valid_0's binary_logloss: 0.163403
# [766]	valid_0's auc: 0.877361	valid_0's binary_logloss: 0.163389
# [767]	valid_0's auc: 0.877372	valid_0's binary_logloss: 0.163384
# [768]	valid_0's auc: 0.877375	valid_0's binary_logloss: 0.163372
# [769]	valid_0's auc: 0.877402	valid_0's binary_logloss: 0.163355
# [770]	valid_0's auc: 0.877413	valid_0's binary_logloss: 0.163345
# [771]	valid_0's auc: 0.877432	valid_0's binary_logloss: 0.163336
# [772]	valid_0's auc: 0.877455	valid_0's binary_logloss: 0.163318
# [773]	valid_0's auc: 0.877465	valid_0's binary_logloss: 0.16331
# [774]	valid_0's auc: 0.877469	valid_0's binary_logloss: 0.163297
# [775]	valid_0's auc: 0.877495	valid_0's binary_logloss: 0.163282
# [776]	valid_0's auc: 0.877504	valid_0's binary_logloss: 0.163277
# [777]	valid_0's auc: 0.877521	valid_0's binary_logloss: 0.163269
# [778]	valid_0's auc: 0.877518	valid_0's binary_logloss: 0.163267
# [779]	valid_0's auc: 0.877532	valid_0's binary_logloss: 0.16325
# [780]	valid_0's auc: 0.877549	valid_0's binary_logloss: 0.163238
# [781]	valid_0's auc: 0.877579	valid_0's binary_logloss: 0.163223
# [782]	valid_0's auc: 0.877589	valid_0's binary_logloss: 0.163215
# [783]	valid_0's auc: 0.877604	valid_0's binary_logloss: 0.163213
# [784]	valid_0's auc: 0.87764	valid_0's binary_logloss: 0.163194
# [785]	valid_0's auc: 0.877635	valid_0's binary_logloss: 0.163196
# [786]	valid_0's auc: 0.87766	valid_0's binary_logloss: 0.163178
# [787]	valid_0's auc: 0.877668	valid_0's binary_logloss: 0.163172
# [788]	valid_0's auc: 0.877685	valid_0's binary_logloss: 0.163155
# [789]	valid_0's auc: 0.877691	valid_0's binary_logloss: 0.163147
# [790]	valid_0's auc: 0.877734	valid_0's binary_logloss: 0.163121
# [791]	valid_0's auc: 0.877745	valid_0's binary_logloss: 0.163109
# [792]	valid_0's auc: 0.877772	valid_0's binary_logloss: 0.163098
# [793]	valid_0's auc: 0.877784	valid_0's binary_logloss: 0.163084
# [794]	valid_0's auc: 0.877781	valid_0's binary_logloss: 0.163082
# [795]	valid_0's auc: 0.877793	valid_0's binary_logloss: 0.163067
# [796]	valid_0's auc: 0.877809	valid_0's binary_logloss: 0.163052
# [797]	valid_0's auc: 0.877814	valid_0's binary_logloss: 0.163047
# [798]	valid_0's auc: 0.877827	valid_0's binary_logloss: 0.163036
# [799]	valid_0's auc: 0.877837	valid_0's binary_logloss: 0.163021
# [800]	valid_0's auc: 0.877852	valid_0's binary_logloss: 0.163011
# [801]	valid_0's auc: 0.877871	valid_0's binary_logloss: 0.162995
# [802]	valid_0's auc: 0.877888	valid_0's binary_logloss: 0.162982
# [803]	valid_0's auc: 0.877888	valid_0's binary_logloss: 0.162979
# [804]	valid_0's auc: 0.877889	valid_0's binary_logloss: 0.162973
# [805]	valid_0's auc: 0.877896	valid_0's binary_logloss: 0.162961
# [806]	valid_0's auc: 0.877899	valid_0's binary_logloss: 0.162956
# [807]	valid_0's auc: 0.877911	valid_0's binary_logloss: 0.162948
# [808]	valid_0's auc: 0.877935	valid_0's binary_logloss: 0.162935
# [809]	valid_0's auc: 0.877939	valid_0's binary_logloss: 0.162929
# [810]	valid_0's auc: 0.877941	valid_0's binary_logloss: 0.162922
# [811]	valid_0's auc: 0.87795	valid_0's binary_logloss: 0.162915
# [812]	valid_0's auc: 0.87799	valid_0's binary_logloss: 0.162892
# [813]	valid_0's auc: 0.878015	valid_0's binary_logloss: 0.162876
# [814]	valid_0's auc: 0.878005	valid_0's binary_logloss: 0.162878
# [815]	valid_0's auc: 0.87801	valid_0's binary_logloss: 0.162873
# [816]	valid_0's auc: 0.878012	valid_0's binary_logloss: 0.162868
# [817]	valid_0's auc: 0.878022	valid_0's binary_logloss: 0.162861
# [818]	valid_0's auc: 0.878028	valid_0's binary_logloss: 0.162856
# [819]	valid_0's auc: 0.878029	valid_0's binary_logloss: 0.162852
# [820]	valid_0's auc: 0.878059	valid_0's binary_logloss: 0.162839
# [821]	valid_0's auc: 0.878073	valid_0's binary_logloss: 0.162831
# [822]	valid_0's auc: 0.878074	valid_0's binary_logloss: 0.162827
# [823]	valid_0's auc: 0.878087	valid_0's binary_logloss: 0.162814
# [824]	valid_0's auc: 0.878107	valid_0's binary_logloss: 0.1628
# [825]	valid_0's auc: 0.878105	valid_0's binary_logloss: 0.162796
# [826]	valid_0's auc: 0.878128	valid_0's binary_logloss: 0.162781
# [827]	valid_0's auc: 0.878142	valid_0's binary_logloss: 0.162773
# [828]	valid_0's auc: 0.878146	valid_0's binary_logloss: 0.162768
# [829]	valid_0's auc: 0.878152	valid_0's binary_logloss: 0.162754
# [830]	valid_0's auc: 0.878166	valid_0's binary_logloss: 0.162743
# [831]	valid_0's auc: 0.878161	valid_0's binary_logloss: 0.16274
# [832]	valid_0's auc: 0.878181	valid_0's binary_logloss: 0.162722
# [833]	valid_0's auc: 0.878194	valid_0's binary_logloss: 0.162713
# [834]	valid_0's auc: 0.878225	valid_0's binary_logloss: 0.16269
# [835]	valid_0's auc: 0.878226	valid_0's binary_logloss: 0.162687
# [836]	valid_0's auc: 0.878226	valid_0's binary_logloss: 0.162678
# [837]	valid_0's auc: 0.878237	valid_0's binary_logloss: 0.16267
# [838]	valid_0's auc: 0.87824	valid_0's binary_logloss: 0.162667
# [839]	valid_0's auc: 0.878255	valid_0's binary_logloss: 0.162654
# [840]	valid_0's auc: 0.878263	valid_0's binary_logloss: 0.162648
# [841]	valid_0's auc: 0.878281	valid_0's binary_logloss: 0.162638
# [842]	valid_0's auc: 0.878277	valid_0's binary_logloss: 0.162637
# [843]	valid_0's auc: 0.878287	valid_0's binary_logloss: 0.162626
# [844]	valid_0's auc: 0.878305	valid_0's binary_logloss: 0.162615
# [845]	valid_0's auc: 0.878311	valid_0's binary_logloss: 0.162604
# [846]	valid_0's auc: 0.878317	valid_0's binary_logloss: 0.162598
# [847]	valid_0's auc: 0.878318	valid_0's binary_logloss: 0.162596
# [848]	valid_0's auc: 0.878338	valid_0's binary_logloss: 0.162579
# [849]	valid_0's auc: 0.878341	valid_0's binary_logloss: 0.162574
# [850]	valid_0's auc: 0.878373	valid_0's binary_logloss: 0.162558
# [851]	valid_0's auc: 0.878372	valid_0's binary_logloss: 0.162555
# [852]	valid_0's auc: 0.878397	valid_0's binary_logloss: 0.162528
# [853]	valid_0's auc: 0.878445	valid_0's binary_logloss: 0.162504
# [854]	valid_0's auc: 0.878454	valid_0's binary_logloss: 0.162492
# [855]	valid_0's auc: 0.878479	valid_0's binary_logloss: 0.162469
# [856]	valid_0's auc: 0.878488	valid_0's binary_logloss: 0.162455
# [857]	valid_0's auc: 0.878497	valid_0's binary_logloss: 0.162446
# [858]	valid_0's auc: 0.878528	valid_0's binary_logloss: 0.162425
# [859]	valid_0's auc: 0.878539	valid_0's binary_logloss: 0.162413
# [860]	valid_0's auc: 0.878542	valid_0's binary_logloss: 0.162409

# %%
def get_clf_eval(test, pred, pred_proba) :
    confusion = confusion_matrix(test, pred)
    accuracy = accuracy_score(test, pred)
    precision = precision_score(test, pred)
    recall = recall_score(test, pred)
    f1 = f1_score(test, pred)
    roc_auc = roc_auc_score(test, pred)
    fpr, tpr, thresholds = roc_curve(test, pred_proba, pos_label = 1)
    
    print("오차행렬")
    print(confusion)
    print(f"정확도 : {accuracy:.4f}, 정밀도 : {precision:.4f}, 재현율 : {recall:.4f}, F1 : {f1:.4f}, AUC : {roc_auc:.4f}")
    return confusion, accuracy, precision, recall, f1, fpr, tpr, thresholds
    
    
confusion, accuracy, precision, recall, f1, fpr, tpr, thresholds = get_clf_eval(y_val, preds, pred_proba)
# Out:
# 오차행렬
# [[952583  18385]
#  [ 43241  12230]]
# 정확도 : 0.9400, 정밀도 : 0.3995, 재현율 : 0.2205, F1 : 0.2841, AUC : 0.6008

# %% [markdown]
# ## roc_auc curve

# %%
def roc_auc_curve_plot(fpr, tpr, fpr_train = None, tpr_train = None, fpr_test=None, tpr_test=None) :
    plt.figure(figsize = (8, 8))
    plt.plot([0,1], [0,1], label = "Random")
    plt.plot(fpr, tpr, label = "ROC_valid")
    
    if fpr_train is not None : 
        plt.plot(fpr_train, tpr_train, label = "ROC_train")
    
    if fpr_test is not None : 
        plt.plot(fpr_test, tpr_test, label = "ROC_test")

    plt.xlabel("FPR")
    plt.ylabel("TPR")

    plt.legend()
    plt.grid()
    plt.show()

# %%
# train_set
pred_proba_train = clf.predict_proba(X_smote)[:, 1]
preds_train = clf.predict(X_smote)

# test set
pred_proba_test = clf.predict_proba(X_test)[:, 1]
preds_test = clf.predict(X_test)

# result
result_train = list(get_clf_eval(y_smote, preds_train, pred_proba_train))
result = list(get_clf_eval(y_test, preds_test, pred_proba_test))

# %%
# result
result_train = list(get_clf_eval(y_smote, preds_train, pred_proba_train))
result = list(get_clf_eval(y_test, preds_test, pred_proba_test))
# Out:
# 오차행렬
# [[7645920  121819]
#  [ 468335 7299404]]
# 정확도 : 0.9620, 정밀도 : 0.9836, 재현율 : 0.9397, F1 : 0.9611, AUC : 0.9620
# 오차행렬
# [[952876  18092]
#  [ 43116  12355]]
# 정확도 : 0.9404, 정밀도 : 0.4058, 재현율 : 0.2227, F1 : 0.2876, AUC : 0.6020

# %%
# Val set , Test set ROC_AUC graphh
roc_auc_curve_plot(fpr, tpr, result_train[5], result_train[6],result[5], result[6])

# %% [markdown]
# # Model Save

# %%
# save model 
save_num = 1

# joblib.dump(clf, f"..\\..\\model\\lgb_{save_num}.pkl")

# load_model 
load_model = joblib.load(f"..\\..\\model\\lgb_{save_num}.pkl")

# %%
# temp
preds_train = load_model.predict(X_smote)

# %% [markdown]
# # Make DBSCAN clustering data (for downsampling)
# - 잘 예측하지 못한 데이터는 줄여주기

# %% [markdown]
# # Make DBSMOTE data (for upsampling)
# - 잘 예측한 것들은 늘려주기

# %%
# y_smote 와 predicts
dbscan_df = y_smote.copy()
dbscan_df["y_pred"] = preds_train

dbscan_df["score"] = dbscan_df["y_pred"] + dbscan_df["is_applied"]

true_index = np.where(dbscan_df["score"] != 2.)
false_index = np.where(dbscan_df["score"] == 2.)

# X_db, y_db : DBSCAN을 하기위한 데이터 셋 (prediction 이 false)
X_db = X_smote.iloc[false_index[0]]
y_db = y_smote.iloc[false_index[0]]

X_db_sm = X_smote.iloc[true_index[0]]
y_db_sm = y_smote.iloc[true_index[0]]

# %%
one_hot_var = ["age_group", "gender", "income_type", "purpose", "day", "product_id_cat", "employment_type",
               "bank_id_cat", "houseown_type", "company_year", "credit_score_cat"]

from sklearn.preprocessing import OneHotEncoder
# one_hot encoding dataframe
onehot_encoder = OneHotEncoder()
onehot = onehot_encoder.fit_transform(X_db[one_hot_var])

onehot = onehot.toarray()
onehot = pd.DataFrame(onehot)
onehot.columns = onehot_encoder.get_features_names()

# min_max_var = list(set(X_db.columns) - set(one_hot_var))
min_max_var = ["credit_score", "loan_rate", "desired_amount", "existing_loan_cnt", "loan_limit", "yearly_income",
              "existing_loan_amt", "total_income"]

# MinMaxScaling
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()
minmax = minmax_scaler.fit_transform(X_db[min_max_var])

# numerical_data
minmax = pd.DataFrame(minmax, columns = min_max_var)

# %%
from sklearn.cluster import DBSCAN
# dummy (one_hot encoding) , min_max_scaling

# dbscan
dbscan = DBSCAN(eps = 0.6, min_samples = 100, metric = "euclidean", n_jobs = -1)
dbscan_labels = dbscan.fit_predict(minmax)

# cluster label 추가
y_db["dbscan_cluster"] = dbscan_labels
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [28], in <cell line: 6>()
#       2 # dummy (one_hot encoding) , min_max_scaling
#       3
#       4 # dbscan
#       5 dbscan = DBSCAN(eps = 0.6, min_samples = 100, metric = "euclidean", n_jobs = -1)
# ----> 6 dbscan_labels = dbscan.fit_predict(minmax)
#       8 # cluster label 추가
#       9 y_db["dbscan_cluster"] = dbscan_labels
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\sklearn\cluster\_dbscan.py:458, in DBSCAN.fit_predict(self, X, y, sample_weight)
#     433 def fit_predict(self, X, y=None, sample_weight=None):
#     434     """Compute clusters from a data or distance matrix and predict labels.
#     435
#     436     Parameters
#    (...)
#     456         Cluster labels. Noisy samples are given the label -1.
#     457     """
# --> 458     self.fit(X, sample_weight=sample_weight)
#     459     return self.labels_
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\sklearn\cluster\_dbscan.py:406, in DBSCAN.fit(self, X, y, sample_weight)
#     404 neighbors_model.fit(X)
#     405 # This has worst case O(n^2) memory complexity
# --> 406 neighborhoods = neighbors_model.radius_neighbors(X, return_distance=False)
#     408 if sample_weight is None:
#     409     n_neighbors = np.array([len(neighbors) for neighbors in neighborhoods])
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\sklearn\neighbors\_base.py:1169, in RadiusNeighborsMixin.radius_neighbors(self, X, radius, return_distance, sort_results)
#    1167 n_jobs = effective_n_jobs(self.n_jobs)
#    1168 delayed_query = delayed(_tree_query_radius_parallel_helper)
# -> 1169 chunked_results = Parallel(n_jobs, prefer="threads")(
#    1170     delayed_query(
#    1171         self._tree, X[s], radius, return_distance, sort_results=sort_results
#    1172     )
#    1173     for s in gen_even_slices(X.shape[0], n_jobs)
#    1174 )
#    1175 if return_distance:
#    1176     neigh_ind, neigh_dist = tuple(zip(*chunked_results))
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File ~\anaconda3\envs\bigcontest\lib\multiprocessing\pool.py:771, in ApplyResult.get(self, timeout)
#     769     return self._value
#     770 else:
# --> 771     raise self._value
#
# File ~\anaconda3\envs\bigcontest\lib\multiprocessing\pool.py:125, in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\joblib\_parallel_backends.py:620, in SafeFunction.__call__(self, *args, **kwargs)
#     618 def __call__(self, *args, **kwargs):
#     619     try:
# --> 620         return self.func(*args, **kwargs)
#     621     except KeyboardInterrupt as e:
#     622         # We capture the KeyboardInterrupt and reraise it as
#     623         # something different, as multiprocessing does not
#     624         # interrupt processing for a KeyboardInterrupt
#     625         raise WorkerInterrupt() from e
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\sklearn\utils\fixes.py:117, in _FuncWrapper.__call__(self, *args, **kwargs)
#     115 def __call__(self, *args, **kwargs):
#     116     with config_context(**self.config):
# --> 117         return self.function(*args, **kwargs)
#
# File ~\anaconda3\envs\bigcontest\lib\site-packages\sklearn\neighbors\_base.py:951, in _tree_query_radius_parallel_helper(tree, *args, **kwargs)
#     945 def _tree_query_radius_parallel_helper(tree, *args, **kwargs):
#     946     """Helper for the Parallel calls in RadiusNeighborsMixin.radius_neighbors.
#     947
#     948     The Cython method tree.query_radius is not directly picklable by
#     949     cloudpickle under PyPy.
#     950     """
# --> 951     return tree.query_radius(*args, **kwargs)
#
# File sklearn\neighbors\_binary_tree.pxi:1375, in sklearn.neighbors._kd_tree.BinaryTree.query_radius()
#
# File sklearn\neighbors\_binary_tree.pxi:1331, in sklearn.neighbors._kd_tree.BinaryTree.query_radius()
#
# MemoryError:

# %%
y_db["dbscan_cluster"].value_counts()

# %%
import lightgbm as lgb
from imblearn.over_sampling import *

smote_ = SMOTE(random_state = 0)

# fitting
X_db_sm, y_db_sm = smote_.fit_resample(X_db_sm, y_db_sm)

# 다시 학습시킬 데이터셋 만들기 + 저장 ?
X_train_new = pd.concat([X_db, X_db_sm], axis = 0).reset_index()
y_train_new = pd.concat([y_db, y_db_sm], axis = 0).reset_index()

# %% [markdown]
# # 10번 반복

# %%
import math
import time
import datetime
import tqdm

pred_proba_ls = []
preds_ls = []
X_df_ls = [X_smote]
y_df_ls = [y_smote]

def greedy_down_up_sampling(X, y,save_num)
    clf = LGBMClassifier(**best_params)

    evals = [(X_val, y_val)]
    clf.fit(X,, y, early_stopping_rounds = 100, eval_metric = "auc",
           eval_set = evals, verbose = True)

    pred_proba = clf.predict_proba(X_val)[:, 1]
    preds = clf.predict(X_val)
    
    pred_proba_ls.append(pred_proba)
    preds_ls.append(preds)
    
    get_clf_eval(y_val, preds, pred_proba)
    
    joblib.dump(clf, f"..\\..\\model\\lgb_{save_num}.pkl")

#     # load_model 
#     load_model = joblib.load(f"..\\..\\model\\lgb_{save_num}.pkl")
    
    # y_smote 와 predicts
    dbscan_df = y.copy()
    dbscan_df["y_pred"] = preds

    dbscan_df["score"] = dbscan_df["y_pred"] + dbscan_df["is_applied"]

    true_index = np.where(dbscan_df["score"] != 2.)
    false_index = np.where(dbscan_df["score"] == 2.)

    # X_db, y_db : DBSCAN을 하기위한 데이터 셋 (prediction 이 false)
    X_db = X.iloc[false_index[0]]
    y_db = y.iloc[false_index[0]]

    X_db_sm = X.iloc[true_index[0]]
    y_db_sm = y.iloc[true_index[0]]
    
    one_hot_var = ["age_group", "gender", "income_type", "purpose", "day", "product_id_cat", "employment_type",
               "bank_id_cat", "houseown_type", "company_year", "credit_score_cat"]

    from sklearn.preprocessing import OneHotEncoder
    # one_hot encoding dataframe
    onehot_encoder = OneHotEncoder()
    onehot = onehot_encoder.fit_transform(X_db[one_hot_var])

    onehot = onehot.toarray()
    onehot = pd.DataFrame(onehot)
    onehot.columns = onehot_encoder.get_features_names()

    # min_max_var = list(set(X_db.columns) - set(one_hot_var))
    min_max_var = ["credit_score", "loan_rate", "desired_amount", "existing_loan_cnt", "loan_limit", "yearly_income",
                  "existing_loan_amt", "total_income"]

    

    minmax_scaler = MinMaxScaler()
    minmax = minmax_scaler.fit_transform(X_db[min_max_var])

    # numerical_data
    minmax = pd.DataFrame(minmax, columns = min_max_var)
    
    # dbscan
    dbscan = DBSCAN(eps = 0.6, min_samples = 100, metric = "euclidean")
    dbscan_labels = dbscan.fit_predict(X_db)

    # cluster label 추가
    y_db["dbscan_cluster"] = dbscan_labels
    
    smote_ = SMOTE(random_state = 0)

    # fitting
    X_db_sm, y_db_sm = smote_.fit_resample(X_db_sm, y_db_sm)

    # 다시 학습시킬 데이터셋 만들기 + 저장 ?
    X_train_new = pd.concat([X_db, X_db_sm], axis = 0).reset_index()
    y_train_new = pd.concat([y_db, y_db_sm], axis = 0).reset_index()
    
    X_df_ls.append(X_train_new)
    y_df_ls.append(y_train_new)
    
    return X_train_new, y_train_new

start = time.time()

for i in tqdm(range(10)) : 
    X, y = X_df_ls[i], y_df_ls[i]
    greedy_down_up_sampling(X, y, i)

# 총 걸리는 시간 측정
end = time.time()
sec = (end - start)

result_time = datetime.timedelta(seconds=sec)
print(result_time)
result_list = str(datetime.timedelta(seconds=sec)).split(".")
print(result_list[0])
